# %%
#imports 
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
df=pd.read_csv("ai-impact-jobs-layoff-risk-dataset.csv")
print(df.index)
print("All columns are")
ai=0
for i in df:
    print(ai,i)
    ai+=1
# Out:
# RangeIndex(start=0, stop=20000, step=1)
# All columns are
# 0 Age
# 1 Education_Level
# 2 Years_of_Experience
# 3 Industry
# 4 Job_Role
# 5 Company_Size
# 6 Job_Level
# 7 Routine_Task_Percentage
# 8 Creativity_Requirement
# 9 Human_Interaction_Level
# 10 AI_Adoption_Level
# 11 Number_of_AI_Tools_Used
# 12 AI_Usage_Hours_Per_Week
# 13 Tasks_Automated_Percentage
# 14 AI_Training_Hours
# 15 Layoff_Risk

# %%
df.shape
# Out:
# (20000, 16)

# %%
df.head(n=10)
# Out:
#    Age Education_Level  Years_of_Experience       Industry  \
# 0   59        Master's                    6        Finance
# 1   44        Master's                   14  Manufacturing
# 2   36      Bachelor's                    7         Retail
# 3   27      Bachelor's                    6        Finance
# 4   49     High School                   12        Finance
# 5   45             PhD                    9        Telecom
# 6   48      Bachelor's                   10             IT
# 7   23        Master's                    2         Retail
# 8   24      Bachelor's                    3             IT
# 9   48        Master's                    6         Retail
#
#                 Job_Role Company_Size Job_Level  Routine_Task_Percentage  \
# 0             Accountant       Medium     Entry                       84
# 1  Production Supervisor        Small     Entry                       30
# 2          Store Manager       Medium    Senior                       12
# ...

# %%
df.sample(n=10)
# Out:
#        Age Education_Level  Years_of_Experience       Industry  \
# 15525   25      Bachelor's                    4     Healthcare
# 13282   22     High School                    1         Retail
# 13320   59      Bachelor's                    0        Telecom
# 19574   53      Bachelor's                    5      Education
# 4289    56             PhD                    4     Healthcare
# 9028    51      Bachelor's                    4  Manufacturing
# 2017    26        Master's                    4      Education
# 18342   43      Bachelor's                   12        Finance
# 1082    33        Master's                   12         Retail
# 13935   21        Master's                    0     Healthcare
#
#                     Job_Role Company_Size Job_Level  Routine_Task_Percentage  \
# 15525                  Nurse        Large     Entry                       64
# 13282        Sales Associate       Medium     Entry                       82
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 16 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Age                         20000 non-null  int64
#  1   Education_Level             20000 non-null  object
#  2   Years_of_Experience         20000 non-null  int64
#  3   Industry                    20000 non-null  object
#  4   Job_Role                    20000 non-null  object
#  5   Company_Size                20000 non-null  object
#  6   Job_Level                   20000 non-null  object
#  7   Routine_Task_Percentage     20000 non-null  int64
#  8   Creativity_Requirement      20000 non-null  int64
#  9   Human_Interaction_Level     20000 non-null  int64
#  10  AI_Adoption_Level           20000 non-null  object
#  11  Number_of_AI_Tools_Used     20000 non-null  int64
#  12  AI_Usage_Hours_Per_Week     20000 non-null  int64
# ...

# %%
df.isnull()
# Out:
#          Age  Education_Level  Years_of_Experience  Industry  Job_Role  \
# 0      False            False                False     False     False
# 1      False            False                False     False     False
# 2      False            False                False     False     False
# 3      False            False                False     False     False
# 4      False            False                False     False     False
# ...      ...              ...                  ...       ...       ...
# 19995  False            False                False     False     False
# 19996  False            False                False     False     False
# 19997  False            False                False     False     False
# 19998  False            False                False     False     False
# 19999  False            False                False     False     False
#
#        Company_Size  Job_Level  Routine_Task_Percentage  \
# 0             False      False                    False
# ...

# %%
print(df.isnull().sum())
print('Total null values')
# Out:
# Age                           0
# Education_Level               0
# Years_of_Experience           0
# Industry                      0
# Job_Role                      0
# Company_Size                  0
# Job_Level                     0
# Routine_Task_Percentage       0
# Creativity_Requirement        0
# Human_Interaction_Level       0
# AI_Adoption_Level             0
# Number_of_AI_Tools_Used       0
# AI_Usage_Hours_Per_Week       0
# Tasks_Automated_Percentage    0
# AI_Training_Hours             0
# Layoff_Risk                   0
# dtype: int64
# Total null values

# %%
df.describe()
# Out:
#                 Age  Years_of_Experience  Routine_Task_Percentage  \
# count  20000.000000         20000.000000             20000.000000
# mean      40.361500             7.265500                51.885500
# std       11.526333             4.720606                24.437808
# min       21.000000             0.000000                10.000000
# 25%       30.000000             4.000000                31.000000
# 50%       40.000000             7.000000                52.000000
# 75%       50.000000            11.000000                73.000000
# max       60.000000            32.000000                94.000000
#
#        Creativity_Requirement  Human_Interaction_Level  \
# count            20000.000000             20000.000000
# mean                47.786700                60.055000
# std                 26.100482                22.267801
# min                  0.000000                20.000000
# 25%                 27.000000                41.000000
# ...

# %%
# Removing null values
df = df.dropna()
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 16 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Age                         20000 non-null  int64
#  1   Education_Level             20000 non-null  object
#  2   Years_of_Experience         20000 non-null  int64
#  3   Industry                    20000 non-null  object
#  4   Job_Role                    20000 non-null  object
#  5   Company_Size                20000 non-null  object
#  6   Job_Level                   20000 non-null  object
#  7   Routine_Task_Percentage     20000 non-null  int64
#  8   Creativity_Requirement      20000 non-null  int64
#  9   Human_Interaction_Level     20000 non-null  int64
#  10  AI_Adoption_Level           20000 non-null  object
#  11  Number_of_AI_Tools_Used     20000 non-null  int64
#  12  AI_Usage_Hours_Per_Week     20000 non-null  int64
# ...

# %%
df.columns
# Out:
# Index(['Age', 'Education_Level', 'Years_of_Experience', 'Industry', 'Job_Role',
#        'Company_Size', 'Job_Level', 'Routine_Task_Percentage',
#        'Creativity_Requirement', 'Human_Interaction_Level',
#        'AI_Adoption_Level', 'Number_of_AI_Tools_Used',
#        'AI_Usage_Hours_Per_Week', 'Tasks_Automated_Percentage',
#        'AI_Training_Hours', 'Layoff_Risk'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 16 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Age                         20000 non-null  int64
#  1   Education_Level             20000 non-null  object
#  2   Years_of_Experience         20000 non-null  int64
#  3   Industry                    20000 non-null  object
#  4   Job_Role                    20000 non-null  object
#  5   Company_Size                20000 non-null  object
#  6   Job_Level                   20000 non-null  object
#  7   Routine_Task_Percentage     20000 non-null  int64
#  8   Creativity_Requirement      20000 non-null  int64
#  9   Human_Interaction_Level     20000 non-null  int64
#  10  AI_Adoption_Level           20000 non-null  object
#  11  Number_of_AI_Tools_Used     20000 non-null  int64
#  12  AI_Usage_Hours_Per_Week     20000 non-null  int64
# ...

# %%
# Plotting only useful columns
grid = sns.pairplot(df,corner=True)

# %%
# For saving the plot
'''


grid.savefig('Layoff.png', dpi=300, bbox_inches='tight')


'''
print('This plot gives us a rough idea of the data')
# Out:
# This plot gives us a rough idea of the data

# %%
plt.figure(figsize=(18,16))
sns.heatmap(df.corr(numeric_only=True),annot=True)
# Out:
# <Axes: >

# %%
df.columns
# Out:
# Index(['Age', 'Education_Level', 'Years_of_Experience', 'Industry', 'Job_Role',
#        'Company_Size', 'Job_Level', 'Routine_Task_Percentage',
#        'Creativity_Requirement', 'Human_Interaction_Level',
#        'AI_Adoption_Level', 'Number_of_AI_Tools_Used',
#        'AI_Usage_Hours_Per_Week', 'Tasks_Automated_Percentage',
#        'AI_Training_Hours', 'Layoff_Risk'],
#       dtype='object')

# %%
df.select_dtypes(include='number').columns
# Out:
# Index(['Age', 'Years_of_Experience', 'Routine_Task_Percentage',
#        'Creativity_Requirement', 'Human_Interaction_Level',
#        'Number_of_AI_Tools_Used', 'AI_Usage_Hours_Per_Week',
#        'Tasks_Automated_Percentage', 'AI_Training_Hours'],
#       dtype='object')

# %%
churnplot = sns.pairplot(
            df,
            vars=df.select_dtypes(include='number').columns,
            hue='Layoff_Risk',
            plot_kws={'alpha':0.5},
            corner = True
            )

# %%
'''

churnplot.savefig('Layoff_RiskCat.png', dpi=300, bbox_inches='tight')

'''

# %%
# Boxplot for outlier detection

numerical_cols = df.select_dtypes(include='number').columns

plt.figure(figsize=(20, 16))
for i, col in enumerate(numerical_cols, 1):
    plt.subplot(3, 3, i)
    sns.boxplot(data=df, y=col, color='skyblue')
    plt.title(f'Boxplot of {col}')

plt.tight_layout()
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 16 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Age                         20000 non-null  int64
#  1   Education_Level             20000 non-null  object
#  2   Years_of_Experience         20000 non-null  int64
#  3   Industry                    20000 non-null  object
#  4   Job_Role                    20000 non-null  object
#  5   Company_Size                20000 non-null  object
#  6   Job_Level                   20000 non-null  object
#  7   Routine_Task_Percentage     20000 non-null  int64
#  8   Creativity_Requirement      20000 non-null  int64
#  9   Human_Interaction_Level     20000 non-null  int64
#  10  AI_Adoption_Level           20000 non-null  object
#  11  Number_of_AI_Tools_Used     20000 non-null  int64
#  12  AI_Usage_Hours_Per_Week     20000 non-null  int64
# ...

# %%
# Checking stats of every category
# 1 is good , 2 is average , 3 is bad

a = 'Layoff_Risk'


adf = df[df[a] == "Low"]
adf.describe()
# Out:
#                Age  Years_of_Experience  Routine_Task_Percentage  \
# count  6602.000000          6602.000000              6602.000000
# mean     40.901242             7.854438                28.540139
# std      11.340922             4.678695                14.363493
# min      21.000000             0.000000                10.000000
# 25%      31.000000             4.000000                17.000000
# 50%      41.000000             8.000000                26.000000
# 75%      51.000000            11.000000                37.000000
# max      60.000000            24.000000                93.000000
#
#        Creativity_Requirement  Human_Interaction_Level  \
# count             6602.000000              6602.000000
# mean                71.926840                64.628143
# std                 16.642965                21.596702
# min                  4.000000                20.000000
# 25%                 61.000000                47.000000
# ...

# %%
bdf = df[df[a] == "Medium"]
bdf.describe()
# Out:
#                Age  Years_of_Experience  Routine_Task_Percentage  \
# count  6601.000000          6601.000000              6601.000000
# mean     40.334495             7.265111                51.255567
# std      11.393562             4.637725                17.718779
# min      21.000000             0.000000                10.000000
# 25%      31.000000             4.000000                38.000000
# 50%      40.000000             7.000000                50.000000
# 75%      50.000000            11.000000                64.000000
# max      60.000000            23.000000                94.000000
#
#        Creativity_Requirement  Human_Interaction_Level  \
# count             6601.000000              6601.000000
# mean                48.296167                59.734586
# std                 19.082461                22.221410
# min                  0.000000                20.000000
# 25%                 35.000000                40.000000
# ...

# %%
cdf = df[df[a] == "High"]
cdf.describe()
# Out:
#                Age  Years_of_Experience  Routine_Task_Percentage  \
# count  6797.000000          6797.000000              6797.000000
# mean     39.863469             6.693836                75.172870
# std      11.808354             4.771036                13.413797
# min      21.000000             0.000000                24.000000
# 25%      30.000000             3.000000                66.000000
# 50%      40.000000             6.000000                77.000000
# 75%      50.000000            10.000000                86.000000
# max      60.000000            32.000000                94.000000
#
#        Creativity_Requirement  Human_Interaction_Level  \
# count             6797.000000              6797.000000
# mean                23.844343                55.924231
# std                 15.567560                22.115966
# min                  0.000000                20.000000
# 25%                 12.000000                36.000000
# ...

# %%
for i in df.select_dtypes(include=['object', 'string']):
    counts = df[i].value_counts()
    print(counts)
# Out:
# Education_Level
# Bachelor's     9967
# Master's       5426
# High School    3558
# PhD            1049
# Name: count, dtype: int64
# Industry
# Telecom          2582
# Healthcare       2561
# Finance          2513
# Logistics        2488
# IT               2483
# Retail           2467
# Manufacturing    2457
# Education        2449
# Name: count, dtype: int64
# Job_Role
# Nurse                    900
# Medical Assistant        889
# Financial Analyst        879
# Support Specialist       873
# Network Engineer         862
# Operator                 858
# Inventory Analyst        857
# Supply Chain Analyst     857
# Data Analyst             849
# Operations Analyst       847
# Warehouse Manager        843
# Software Engineer        829
# Accountant               821
# Academic Coordinator     819
# Research Assistant       818
# Auditor                  813
# Teacher                  812
# Sales Associate          807
# Production Supervisor    806
# ML Engineer              805
# ...
